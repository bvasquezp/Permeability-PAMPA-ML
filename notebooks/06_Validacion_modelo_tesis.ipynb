# %% [markdown]
# # 06. Validación del modelo final de tesis
#
# Este notebook verifica que el modelo serializado `models/best_rf_pampa.pkl` reproduce las métricas finales guardadas.
#
# ## Qué debe cambiar el usuario
#
# Para validar la tesis, no cambies nada. Si entrenas otro modelo, cambia `models/best_rf_pampa.pkl` en la celda de carga del modelo y compara sus métricas con el modelo oficial.

# %%
from pathlib import Path
import joblib
import pandas as pd

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
# %cd $ROOT

# %% [markdown]
# ## Reproducción automática de métricas

# %%
# !python src/check_final_metrics.py

# %% [markdown]
# ## Contrato de descriptores del modelo

# %%
model = joblib.load('models/best_rf_pampa.pkl')
list(model.feature_names_in_)

# %% [markdown]
# ## Métricas almacenadas

# %%
pd.read_csv('results/metrics/evaluacion_final_datasets.csv')

# %% [markdown]
# ## Comparación del pipeline reconstruido

# %%
pd.read_csv('results/thesis_feature_pipeline/optimized_vs_thesis_exact.csv')
